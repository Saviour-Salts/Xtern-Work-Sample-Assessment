# %% [markdown]
# In the cell below, I imported the libraries I would be using in the project.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# In the cell below, I used Google Map to find the distance from the housing to each coworking and used the Pandas library to report the summary of my findings

# %%
distance_df = pd.read_csv('distance.txt')
distance_df
# Out:
#         COWORKING SPACE                                            ADDRESS  \
# 0           Launch Indy            525 S Meridian St Indianapolis IN 46225
# 1  Industrious Mass Ave  350 Massachusetts Ave. Suite 300 Indianapolis ...
# 2        Launch Fishers               12175 Visionary Way Fishers IN 46038
# 3                zWORKS           85 E Cedar St. #1502 Zionsville IN 46077
# 4         The Speak Way       5255 Winthrop Ave #110 Indianapolis IN 46220
#
#    DISTANCE FROM HOUSING (IN MILES)
# 0                               2.5
# 1                               1.9
# 2                              18.0
# 3                              17.0
# 4                               7.2

# %% [markdown]
# In the cell below, I used the resoureces available to research on the essential services or amenities provided by each coworking space and presented my findings as a dataframe using the Pandas Library. I used "1" and "0" to represent the availability and unavailability of an essential amenity or service respectively.

# %%
services_df = pd.read_csv('services.csv')
services_df
# Out:
#                              ESSENTIAL AMENITIES  Launch Indy  \
# 0                                 Access Control            0
# 1                    Wireless and Wired Internet            1
# 2   Furnished Offices with Comfortable Furniture            1
# 3                                  Meeting Rooms            1
# 4                  Printing and Copying Services            1
# 5                    Free and Convenient Parking            1
# 6                            Kitchen/Eating Area            0
# 7                                   Mail Service            1
# 8                              Recreational Area            0
# 9                                Clean Washrooms            1
# 10                                Coffee Machine            1
# 11                                  Total Points            8
#
#     Industrious Mass Ave  Launch Fishers  zWORKS  The Speak Easy
# 0                      1               1       1               1
# ...

# %% [markdown]
# In the cell below, I considered the fact that we would need a conference room to host a conference or Ted Talk event. I got the total of the essential services provided by each coworking space as well.

# %%
coworking_df = pd.read_csv('coworking.txt')
coworking_df
# Out:
#         COWORKING SPACE                                            ADDRESS  \
# 0           Launch Indy            525 S Meridian St Indianapolis IN 46225
# 1  Industrious Mass Ave  350 Massachusetts Ave. Suite 300 Indianapolis ...
# 2        Launch Fishers               12175 Visionary Way Fishers IN 46038
# 3                zWORKS           85 E Cedar St. #1502 Zionsville IN 46077
# 4         The Speak Way       5255 Winthrop Ave #110 Indianapolis IN 46220
#
#    DISTANCE FROM HOUSING (IN MILES)  ESSENTIAL AMENITIES POINTS  \
# 0                               2.5                           8
# 1                               1.9                          10
# 2                              18.0                           7
# 3                              17.0                           7
# 4                               7.2                           5
#
#   AVAILABILITY OF CONFERENCE ROOM
# 0                              No
# 1                             Yes
# ...

# %% [markdown]
# In the cell below, using an "If statement", I was able to select the most convenient coworking space using factors such as distance from housing, total points from essential services provided and wheter or not the coworking space has a conference room to host the Ted Talk event. It appears that the coworking space "Industrious Mass Ave" is the most convenient coworking space that meets all of those requirements.

# %%
sorted_coworking = []
for index, row in coworking_df.iterrows():
    if row[2] <= 8.0 and row[3] >= 8 and row[4] == "Yes":
        sorted_coworking.append(row[0])
print("The most convenient Coworking Space is or Coworking Spaces are: ",sorted_coworking)
# Out:
# The most convenient Coworking Space is or Coworking Spaces are:  ['Industrious Mass Ave']

# %% [markdown]
# In the next cell, I randomly selected 18 restaurants around the housing area. With the help of Google, I was able to gather this information. I then used Google Map to find the distance from the housing to each restaurant and further considered the cost of using each restaurant per person. I was also interested in the time each restaurant operates on Saturday because I planned that the weekly dinner would be on every Saturday evening in the space of 10 weeks.

# %%
restaurant_df = pd.read_csv('restaurants.txt')
restaurant_df
# Out:
#     RANDOMLY SELECTED RESTAURANTS IN INDY  DISTANCE FROM HOUSING  \
# 0                    St. Elmo Steak House                    2.1
# 1                          Bazbeaux Pizza                    1.9
# 2                          BRU Burger Bar                    2.0
# 3                                    Yats                    2.9
# 4                          Shapiro's Deli                    2.6
# 5               Jockamo Upper Crust Pizza                    6.4
# 6   Mama Carolla's Old Italian Restaurant                    7.5
# 7                        Harry and Izzy's                    2.1
# 8                               Bluebeard                    3.0
# 9                                  Livery                    2.7
# 10                        The Rathskeller                    2.6
# 11                       Goose the Market                    3.6
# 12                   Rick's Cafe Boatyard                    9.7
# ...

# %% [markdown]
# In the cell below, using an "If statement", I was able to select the most convenient restaurants using factors such as distance from housing and cost per person in each restaurant. It appears that the restaurants that would be convenient are: Bazbeaux Pizza, BRU Bruger Bar, Yats, Shapiro's Deli, Bluebeard, Goose the Market, Laria's Italian Restaurant, Union 50, Mug 'N Bun and Big Lug Canteen. The details of how I arrived at the above list is spelled out in my written analysis.

# %%
sorted_restaurants = []
for index, row in restaurant_df.iterrows():
    if row[1] <= 8.0 and row[2] == "12 and under" or ( row[1] <= 6.0 and row[2] == "12 to 24"):
        sorted_restaurants.append(row[0])
print("The most convenient restaurants amongst the randomly selected ones are: ",sorted_restaurants)
# Out:
# The most convenient restaurants amongst the randomly selected ones are:  ['Bazbeaux Pizza', 'BRU Burger Bar', 'Yats', "Shapiro's Deli", 'Bluebeard', 'Goose the Market', "Laria's Italian Restaurant", 'Union 50', "Mug 'N Bun", 'Big Lug Canteen']

# %% [markdown]
# Using Eventbrite, I gathered event locations for a biweekly sport, gaming, music and art event. I used factors such as distance from the housing and distance from the selected coworking space in addition to the amount of money one person would spend for an event to arrive at this selection and conclusion. I then presented a sample 10-week activities plan with the event date and time, event location and event details as a dataframe using the Pandas library. Details of this process is metioned in my written analysis.

# %%
sample_df = pd.read_csv('sample.txt')
sample_df
# Out:
#                                  EVENT NAME        DATE  \
# 0                  Dinner at Baxbeaux Pizza  10/23/2021
# 1        Indiana Pacers vs. Milwaukee Bucks  10/29/2021
# 2                         Infamous Art Fair  10/29/2021
# 3                   Power Clean Competition  10/30/2021
# 4                  Dinner at BRU Burger Bar  10/30/2021
# 5               Afrobeats Sundays Day Party  10/31/2021
# 6                            Dinner at Yats   11/6/2021
# 7                                Game Night  11/12/2021
# 8                             Bad Art Night  11/12/2021
# 9              The Hard Charger 5K Run/Walk  11/13/2021
# 10                 Dinner at Shapiro's Deli  11/13/2021
# 11                 Cory Asbury - Songs Tour  11/14/2021
# 12                      Dinner at Bluebeard  11/20/2021
# 13                                 Game Day  11/26/2021
# 14                 Art Show and Pop Up Shop  11/26/2021
# 15                Punch For Veterans Boxing  11/27/2021
# ...

# %% [markdown]
# ## Written Analysis

# %% [markdown]
# Firstly, I realized that the address for one of the coworking spaces was not provided and so I had to get the right address using Google Map and also made sure that all the addresses provided were accurate. After I got all the addresses for the coworking spaces, I took into consideration the distance from the housing facility to each coworking space and the esential amenities available at each coworking space. Initially, I took into account the cost of using/renting each coworking space. However, due to unavailability in how some of these coworking spaces rented out their place, it did not become necessary to include it in my data.
# I then used factors such as distance from the housing facility to each coworking space and the number of essential services provided by each coworking space and the availability of a conference room to host a Ted Talk, to select the most convenient coworking space. The selection process was such that I placed a threshold on the distance between the cowroking space and the hosuing facility, I chose 8 miles as the threshold because that seemed like a 'normal' distance distance to travel to get to work from home. I was also interested in those coworking spaces that had at least 8 out of the 11 essential amenities provided by an 'average' coworking space. After considering these factors, I wrote a code in python to select the most convenient coworking space. The results from the analysis showed that "Industrious Mass Ave" is the most convenient coworking space. Because the results from the analysis gave us just one coworking space, there was no need to further analyze the data since all we needed was just one coworking space. However, if the result of the analysis listed more than one coworking space, then we would need more factors to continue the analysis until the most convenient coworking space is selected. In that case, we would want to go into details about the cost of renting each coworking space.
#
# Moreover, with the help of Google Map, I randomly selected 18 restaurants (these restaurants were selected so that the probability of having the same meal every week is very minimal) near the housing facility. The reason for this is that it was assumed that Xterns would go to for their weekly dinner from home and not go from the selected coworking space. I gathered the names of the restaurants, their respective distances from the housing unit, the amount that could be spent on food per person and their opening hours on Saturdays and presented the data as a dataframe using the pandas library in python. I was only interested in their Saturday working hours because it was assumed that Xterns would have their weekly dinner on Saturdays. Again, using factors such as distance from the housing facility to the restaurants, cost of food in the restaurants per person, I was able to reduce the number of restaurants from 18 to 6. However, because we needed 10 different restaurants for the 10-week plan, I slightly increased the threshold placed on the distance and cost and finally, I was able to get exactly 10 different restaurants upon the adjustment of the thresholds. For this, the threshold placed was such that the distance is in a radius of 8 miles from the housing facility and the cost of food per person is USD12 and below or the disance is in a radius of 6 miles from the housing facility and the cost of food per person is between USD12 and USD24.
#
# The 10-week period I proposed for this sample is October 18, 2021 to December 27, 2021. Using EventBrite, I was able to put together some exciting sporting, gaming, music and art events that would be happening in the aforementioned time frame in Indianapolis. I refined my search using factors such as cost of attendance per person, date and time for event and distance from both the housing facility and the selected coworking space. The reason I considered both distances was because for some of the events, Xterns would have to go from the coworking space whlies for the rest, they would have to go from the housing facility to the event location. I then presented a sample 10-week activities plan which includes a weekly dinner in the earlier selected restaurants, a biweekly sport, gaming, music and art event, and one Ted Talk event. The summary of the results was presented also adds the event date and time, event location and distances from the hosuing facility and the selected coworking space.
#
# Lastly, it is important to mention that I presented my findings in each step using a dataframe since my data was not large and it could easily be read. Notwithstanding, one may choose to use data visualization to understand the results but I did not use that because my data, its analysis and results was relatively easier to understand even withouth using data visualization.
#
# In conclusion, I was was able to to use available resources and the initial set of data given to me to select the most convenient coworking space, and also present a sample 10-week activities plan which includes a weekly dinner at different restaurants, a biweekly sport, gaming, music and art event, and one Ted Talk event as required.
